# %% [markdown]
# # Possible Crafting Analysis Example
#
# Note 1: The structure is generated with ChatGPT, based on the pure Python example in [`example_calculator_for_example_items.py`](https://github.com/WladHD/pyoe2-craftpath/tree/main/python_examples/example_calculator_for_example_items.py).
#
# Note 2: The start and target item was provided by [github/Dboire9](https://github.com/Dboire9/), thanks!
#
# This notebook demonstrates an example workflow for calculating crafting routes in Path of Exile 2. It includes:
# - Loading example start and target items.
# - Fetching economy and item data.
# - Generating an item matrix and computing statistics.
# - Displaying results in interactive Pandas tables with pretty-print for each route.
# - Summary of top routes and currency groups.

# %% [markdown]
# ## 1. Imports and Version Check
# Import necessary modules for PoE2 crafting analysis, JSON parsing, and Pandas display.
#
# Check for new version

# %%
import pyoe2_craftpath as pc
import pandas as pd

new_version_available = pc.check_for_updates_and_print()
# Out:
# 2025-12-12T21:31:51.142888Z  INFO You are up to date running pyoe2-craftpath with version 0.5.0!
# You can always check out https://github.com/WladHD/pyoe2-craftpath if you encounter issues or have ideas.

# %% [markdown]
# ## 2. Setup Cache and URLs
# Define URLs for item data ([Craft of Exile](https://www.craftofexile.com/?game=poe2)) and market data ([PoE Ninja](https://poe.ninja/)). The economy data is gathered for the League `Standard`.

# %%
COE_MAP = {
    "./cache/coe2.json": "https://www.craftofexile.com/json/poe2/main/poec_data.json"
}

ECONOMY_MAP = {
    "./cache/pn_abyss.json": "https://poe.ninja/poe2/api/economy/exchange/current/overview?league=Standard&type=Abyss",
    "./cache/pn_currency.json": "https://poe.ninja/poe2/api/economy/exchange/current/overview?league=Standard&type=Currency",
    "./cache/pn_essences.json": "https://poe.ninja/poe2/api/economy/exchange/current/overview?league=Standard&type=Essences",
    "./cache/pn_ritual.json": "https://poe.ninja/poe2/api/economy/exchange/current/overview?league=Standard&type=Ritual"
}

# %% [markdown]
# ## 3. Fetch and Parse Item and Market Data
# I've implemented a caching function, that can fetch and cache the given structure in `COE_MAP` and `ECONOMY_MAP`. Use that or provide required CoE's and PN's jsons on your own.

# %%
raw_fetched_responses_coe = pc.retrieve_contents_from_urls_with_cache_unstable_order(
    cache_url_map=COE_MAP,
    max_cache_duration_in_sec=60*60*24
)

raw_fetched_responses_economy = pc.retrieve_contents_from_urls_with_cache_unstable_order(
    cache_url_map=ECONOMY_MAP,
    max_cache_duration_in_sec=60*60
)

coe_data = pc.CraftOfExileItemInfoProvider.parse_from_json(
    raw_fetched_responses_coe[0])
economy = pc.PoeNinjaMarketPriceProvider.parse_from_json_list(
    raw_fetched_responses_economy)
# Out:
# 2025-12-12T21:31:51.163113Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/coe2.json'
# 2025-12-12T21:31:51.180232Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/pn_currency.json'
# 2025-12-12T21:31:51.184973Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/pn_abyss.json'
# 2025-12-12T21:31:51.188716Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/pn_ritual.json'
# 2025-12-12T21:31:51.193529Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/pn_essences.json'

# %% [markdown]
# ## 4. Load Example Items
# Load raw string for starting and target items and parse using the `CraftOfExileEmulatorItemImport` class. The content of `startitem_good_essence_bow.json` and `targetitem_good_essence_bow.json` is generated by the Emulator in [craftofexile.com](https://www.craftofexile.com/?game=poe2) using the Export function (under History/Spending on the right).

# %%
with open('example_items/startitem_good_essence_bow.json', 'r', encoding='utf-8') as f:
    start_raw_string = f.read()
with open('example_items/targetitem_good_essence_bow.json', 'r', encoding='utf-8') as f:
    end_raw_string = f.read()

start_item = pc.CraftOfExileEmulatorItemImport.parse_itemsnapshot_from_string(
    start_raw_string, coe_data)
end_item = pc.CraftOfExileEmulatorItemImport.parse_itemsnapshot_from_string(
    end_raw_string, coe_data)

print(start_item.to_pretty_string(coe_data, True))
print(end_item.to_pretty_string(coe_data, True))
# Out:
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# [Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# [Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Rare, ItemLevel: 100, Sockets: 0
# [Tier 1+, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# [Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# [Tier 1+, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# [Tier 3+, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# [Tier 1+, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# [Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'

# %% [markdown]
# ## 5. Generate Item Matrix
# Use `MatrixBuilderPreset.HappyPathMatrixBuilder` to create a crafting matrix from start to target items. Currently only one implementation exists to build the item matrix. Refer to the [README](https://github.com/WladHD/pyoe2-craftpath) for implementation details. You can write your own Rust addon and create a new `DynMatrixBuilder`, which can be passed as the argument `matrix_builder`.

# %%
matrix_builder_instance = pc.MatrixBuilderPreset.HappyPathMatrixBuilder.get_instance()

calc = pc.Calculator.generate_item_matrix(
    starting_item=start_item,
    target=end_item,
    item_provider=coe_data,
    market_info=economy,
    matrix_builder=matrix_builder_instance
)

print(f"Matrix contains {len(calc.matrix)} items")
# Out:
# Matrix contains 686 items
# 2025-12-12T21:31:51.445242Z  INFO generate_item_matrix: Using 'Happy Path Matrix Builder' to generate item matrix ...
# 2025-12-12T21:31:51.445289Z  INFO generate_item_matrix: Description: Builds an optimized item matrix containing reachable items starting from the given item, that only come closer to the target item (target_proximity).
# 2025-12-12T21:31:51.445320Z  INFO generate_item_matrix: Starting propagation ...
# 2025-12-12T21:31:51.460058Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.460086Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.460098Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.461836Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.461866Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.461879Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.465892Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.465919Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.465930Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.472171Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.472198Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.472210Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.475963Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.475985Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.475997Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.483960Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.483988Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.484000Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.485699Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.485727Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.485739Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.487364Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.487383Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.487394Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.491039Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.491062Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.491073Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.494065Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.494091Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.494103Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.497461Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.497480Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.497492Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.500226Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.500255Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.500266Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.503618Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.503639Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.503651Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.506515Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.506540Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.506552Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.510831Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.510853Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.510865Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.514296Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.514324Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.514335Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.518643Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.518663Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.518675Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.521643Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.521670Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.521682Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.526725Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.526751Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.526763Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.537763Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.537791Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.537803Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.542413Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.542441Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.542453Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.551254Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.551278Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.551289Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.564500Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.564528Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.564540Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.564551Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.592484Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.592512Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.592524Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.592537Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.599103Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.599131Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.599143Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.599153Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.621270Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.621297Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.621309Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.621320Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.664408Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.664437Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.664450Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.664460Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.704933Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.704960Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.704972Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.704982Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.749178Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.749208Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.749220Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.749231Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.774193Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.774222Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.774234Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.774244Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.791997Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.792026Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.792037Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.792048Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.808974Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.809000Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.809012Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.809022Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.818661Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.818684Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.818696Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.818710Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.832855Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.832879Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.832891Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.832922Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.869638Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.869665Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.869677Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.869687Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.870548Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.870564Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.870576Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.870586Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.907976Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.908005Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.908017Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.908028Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.915556Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.915580Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.915592Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.915603Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.916543Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.916560Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.916572Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.916582Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.919491Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.919508Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.919520Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.919530Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.924479Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:51.924499Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.924511Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.924521Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.952047Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.952075Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.952086Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.952099Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.983123Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.983149Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.983161Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.983171Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.989528Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:51.989551Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:51.989563Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:51.989574Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.002854Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.002878Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.002889Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.002900Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.014738Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.014762Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.014774Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.014784Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.019394Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.019420Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.019432Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.019442Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.058193Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.058219Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.058231Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.058242Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.061263Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.061283Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.061295Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.061305Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.062252Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.062268Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.062280Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.062290Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.089173Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.089204Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.089216Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.089230Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.097932Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.097959Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.097971Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.097981Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.132577Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.132606Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.132618Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.132628Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.147703Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.147733Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.147745Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.147755Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.148590Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.148607Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.148619Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.148629Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.183312Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.183346Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.183359Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.183369Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.184208Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.184226Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.184237Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.184247Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.187773Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.187798Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.187810Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.187820Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.188798Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.188838Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.188858Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.188869Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.202310Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.202342Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.202354Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.202369Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.208259Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.208293Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.208305Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.208315Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.218294Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.218322Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.218334Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.218344Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.247426Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.247457Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.247469Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.247480Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.277165Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-12T21:31:52.277194Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.277206Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.277216Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.417361Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.417391Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.417404Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.417414Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.442031Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-12T21:31:52.442053Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-12T21:31:52.442065Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.442076Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-12T21:31:52.928714Z  INFO generate_item_matrix: Excluded 1624 more expensive routes with same chance successfully
# 2025-12-12T21:31:52.928741Z  INFO generate_item_matrix: Successfully generated item matrix.

# %% [markdown]
# ## 6. Calculate Statistics
# Compute crafting statistics using analyzers for chance, efficiency, and cost. Here again, analyzer instances are of type `DynStatisticAnalyzerPaths`, if you want to handle the statistic login in Rust. You can also let this program calculate all possible paths, and create your own statistics in Python yourself.

# %%
def calculate_stat_results(calc: pc.Calculator, analyzer_preset: pc.StatisticAnalyzerPathPreset, coe_data: pc.ItemInfoProvider, economy: pc.MarketPriceProvider, max_routes=100):
    instance = analyzer_preset.get_instance()
    res = calc.calculate_statistics(
        item_provider=coe_data,
        market_provider=economy,
        max_routes=max_routes,
        max_ram_in_bytes=1_000_000_000,
        statistic_analyzer=instance
    )
    return res, instance


chance_results, chance_instance = calculate_stat_results(
    calc, pc.StatisticAnalyzerPathPreset.UniquePathChance, coe_data, economy)
efficiency_results, efficiency_instance = calculate_stat_results(
    calc, pc.StatisticAnalyzerPathPreset.UniquePathEfficiency, coe_data, economy)
cost_results, cost_instance = calculate_stat_results(
    calc, pc.StatisticAnalyzerPathPreset.UniquePathCost, coe_data, economy)
# Out:
# 2025-12-12T21:31:52.949817Z  INFO calculate_statistics: Using 'Unique Path by Highest Chance' to calculate statistics ...
# 2025-12-12T21:31:52.949865Z  INFO calculate_statistics: Description: Retrieves N number of unique paths memory efficiently from all possible combinations, sorted by chance.
# 2025-12-12T21:31:52.949898Z  INFO calculate_statistics:get_statistic: Generating unique craft paths based on item matrix
# 2025-12-12T21:31:53.084730Z  INFO calculate_statistics:get_statistic:finalize_routes: Collecting 100 routes ...
# 2025-12-12T21:31:53.085316Z  INFO calculate_statistics:get_statistic:finalize_routes: Routes collected successfully.
# 2025-12-12T21:31:53.085368Z  INFO calculate_statistics: Successfully calculated statistics.
# 2025-12-12T21:31:53.085602Z  INFO calculate_statistics: Using 'Unique Path by Efficient Cost' to calculate statistics ...
# 2025-12-12T21:31:53.085615Z  INFO calculate_statistics: Description: Retrieves N number of unique paths memory efficiently from all possible combinations, sorted by cost multiplied by amount of tries needed to reach at least 60% chance to gain the item.
# 2025-12-12T21:31:53.085632Z  INFO calculate_statistics:get_statistic: Generating unique craft paths based on item matrix
# 2025-12-12T21:31:53.429360Z  INFO calculate_statistics:get_statistic:finalize_routes: Collecting 100 routes ...
# 2025-12-12T21:31:53.429869Z  INFO calculate_statistics:get_statistic:finalize_routes: Routes collected successfully.
# 2025-12-12T21:31:53.429916Z  INFO calculate_statistics: Successfully calculated statistics.
# 2025-12-12T21:31:53.430134Z  INFO calculate_statistics: Using 'Unique Path by Lowest Cost' to calculate statistics ...
# 2025-12-12T21:31:53.430146Z  INFO calculate_statistics: Description: Retrieves N number of unique paths memory efficiently from all possible combinations, sorted by cost.
# 2025-12-12T21:31:53.430163Z  INFO calculate_statistics:get_statistic: Generating unique craft paths based on item matrix
# 2025-12-12T21:31:54.003773Z  INFO calculate_statistics:get_statistic:finalize_routes: Collecting 100 routes ...
# 2025-12-12T21:31:54.004253Z  INFO calculate_statistics:get_statistic:finalize_routes: Routes collected successfully.
# 2025-12-12T21:31:54.004304Z  INFO calculate_statistics: Successfully calculated statistics.

# %% [markdown]
# ## 7. Calculate Currency Group Statistics
# Compute grouped statistics using `CurrencyGroupChance` analyzer. Same as unique paths, but with the goal of collecting routes into groups by the applied currency sequence. The instance is `DynStatisticAnalyzerCurrencyGroups`.
#
# The calculation is memory expensive for deep paths, so define the amount of RAM you're comfortable with giving for this calculation.

# %%
group_chance_instance = pc.StatisticAnalyzerCurrencyGroupPreset.CurrencyGroupChance.get_instance()
groups = calc.calculate_statistics_currency_group(
    item_provider=coe_data,
    market_provider=economy,
    max_ram_in_bytes=1_000_000_000,
    statistic_analyzer=group_chance_instance
)
# Out:
# 2025-12-12T21:31:54.011395Z  INFO calculate_statistics_currency_group: Using 'Currency Groups by Highest Chance (No Unique Paths)' to calculate statistics ...
# 2025-12-12T21:31:54.011440Z  INFO calculate_statistics_currency_group: Description: Memory efficient implementation of currency sequence grouping. Unique paths are not kept, but instead immediatly summed, thus losing information but allowing memory efficient collection. Best combined with best N routes.
# 2025-12-12T21:31:54.011471Z  INFO calculate_statistics_currency_group:get_statistic:get_grouped_statistic_memory_efficient: Generating unique craft paths based on item matrix
# 2025-12-12T21:31:55.163410Z  INFO calculate_statistics_currency_group: Successfully calculated statistics.

# %% [markdown]
# ## 8. Build Pandas DataFrames for Routes
# Here is an example, of how the calculated data can be transformed, into a more interesting view. Keep in mind that a route per se has no name. So the position in the sorted list is to identify it (in this example).
#
# Construct DataFrames for chance, efficiency, and cost results with pretty-printed routes.

# %%
def build_routes_df(routes: list[pc.ItemRoute], analyzer_instance: pc.DynStatisticAnalyzerPaths, coe_data: pc.ItemInfoProvider, economy: pc.MarketPriceProvider, calc: pc.Calculator, groups: list[pc.GroupRoute]):
    data = []
    for i, r in enumerate(routes):
        group = r.locate_group(calculated_groups=groups)

        currency_group = [node.currency_list for node in r.route]

        data.append({
            'Route': "#" + str(i + 1),
            'Chance': r.chance,
            'Cost per 1 (DIV)': analyzer_instance.calculate_cost_per_craft(currency_group, coe_data, economy).get_divine_value(),
            'Tries needed for 60 %': analyzer_instance.calculate_tries_needed_for_60_percent(r),
            'Group Chance': group.chance if group is not None else None,
            'Group Tries Needed':  group_chance_instance.calculate_tries_needed_for_60_percent(group) if group is not None else None,
            'Pretty Print': r.to_pretty_string(
                item_provider=coe_data,
                market_provider=economy,
                calculator=calc,
                groups=groups,
                statistic_analyzer=analyzer_instance
            )
        })
    return pd.DataFrame(data)


df_chance = build_routes_df(
    chance_results, chance_instance, coe_data, economy, calc, groups)
df_efficiency = build_routes_df(
    efficiency_results, efficiency_instance, coe_data, economy, calc, groups)
df_cost = build_routes_df(cost_results, cost_instance,
                          coe_data, economy, calc, groups)

# %% [markdown]
# ### 9. Display Top Routes by Chance
# Show a Pandas DataFrame and print pretty-printed route details.
#
# Below is a simple example of how the calculated data can be used. Following examples show a printed table, as well as the raw console output I've coded to visualize routes. The information you want may be different, so adapt to your needs.

# %%
df_chance.head(3)
# Out:
#   Route               Chance  Cost per 1 (DIV)  Tries needed for 60 %  \
# 0    #1  0.07291666666666666          4.028605                     13
# 1    #2  0.07291666666666666          4.028605                     13
# 2    #3  0.07291666666666666          4.028605                     13
#
#           Group Chance  Group Tries Needed  \
# 0  0.07291666666666666                  13
# 1  0.07291666666666666                  13
# 2  0.07291666666666666                  13
#
#                                         Pretty Print
# 0  Group Chance: 7.29167% | Unique Routes: 1 | Tr...
# 1  Group Chance: 7.29167% | Unique Routes: 1 | Tr...
# 2  Group Chance: 7.29167% | Unique Routes: 1 | Tr...

# %%
for i, (_, row) in enumerate(df_chance.head(3).iterrows(), start=1):
    print(f"--- Route {i}: {row['Route']} ---")
    print(row['Pretty Print'])
# Out:
# --- Route 1: #1 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 1. Greater Essence of Abrasion (48 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 50.00000%]
# 6. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
# 7. Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (48 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 4. Apply Exalted Orb (2 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 5.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 5.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 6. Apply Perfect Essence of Electricity (369 EX)
# 6.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 6.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 7. Apply Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 2: #2 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 1. Greater Essence of Abrasion (48 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 50.00000%]
# 6. Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 43.75000%]
# 7. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (48 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 4. Apply Exalted Orb (2 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 5.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 5.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 6. Apply Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 6.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
# 7. Apply Perfect Essence of Electricity (369 EX)
# 7.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 7.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
#
# --- Route 3: #3 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 1. Greater Essence of Abrasion (48 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
# 6. Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 50.00000%]
# 7. Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (48 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 4. Apply Exalted Orb (2 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Electricity (369 EX)
# 5.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 5.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 6. Apply Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 6.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 6.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 7. Apply Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'

# %% [markdown]
# ### 10. Console Display Top Routes by Efficiency

# %%
df_efficiency.head(3)
# Out:
#   Route               Chance  Cost per 1 (DIV)  Tries needed for 60 %  \
# 0    #1  0.07291666666666666          4.028605                     13
# 1    #2  0.07291666666666666          4.028605                     13
# 2    #3  0.07291666666666666          4.028605                     13
#
#           Group Chance  Group Tries Needed  \
# 0  0.07291666666666666                  13
# 1  0.07291666666666666                  13
# 2  0.07291666666666666                  13
#
#                                         Pretty Print
# 0  Group Chance: 7.29167% | Unique Routes: 1 | Tr...
# 1  Group Chance: 7.29167% | Unique Routes: 1 | Tr...
# 2  Group Chance: 7.29167% | Unique Routes: 1 | Tr...

# %%
for i, (_, row) in enumerate(df_efficiency.head(3).iterrows(), start=1):
    print(f"--- Route {i}: {row['Route']} ---")
    print(row['Pretty Print'])
# Out:
# --- Route 1: #1 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 1. Greater Essence of Abrasion (48 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 50.00000%]
# 6. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
# 7. Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (48 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 4. Apply Exalted Orb (2 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 5.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 5.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 6. Apply Perfect Essence of Electricity (369 EX)
# 6.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 6.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 7. Apply Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 2: #2 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 1. Greater Essence of Abrasion (48 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
# 6. Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 50.00000%]
# 7. Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (48 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 4. Apply Exalted Orb (2 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Electricity (369 EX)
# 5.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 5.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 6. Apply Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 6.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 6.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 7. Apply Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 3: #3 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 1. Greater Essence of Abrasion (48 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX) [ROUGH (!) avg. chance: 50.00000%]
# 6. Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 43.75000%]
# 7. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 8,908 EX | Cost for 60%: 115,795 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (48 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (2 EX) + Omen of Sinistral Exaltation (62 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Haste (3,405 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 4. Apply Exalted Orb (2 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Battle (1,400 EX) + Omen of Dextral Crystallisation (1,425 EX)
# 5.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 5.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 6. Apply Omen of Abyssal Echoes (724 EX) + Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 6.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
# 7. Apply Perfect Essence of Electricity (369 EX)
# 7.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 7.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'

# %% [markdown]
# ### 11. Console Display Top Routes by Cost

# %%
df_cost.head(3)
# Out:
#   Route                   Chance  Cost per 1 (DIV)  Tries needed for 60 %  \
# 0    #1    6.2574372698838806e-6          2.363795                 146432
# 1    #2  0.000011364979746181782          2.363795                  80624
# 2    #3   0.00001420102653766467          2.363795                  64523
#
#               Group Chance  Group Tries Needed  \
# 0   0.00002045846380754855               44788
# 1  0.000022729959492363564               40312
# 2    0.0000202583612689384               45230
#
#                                         Pretty Print
# 0  Group Chance: 0.00205% | Unique Routes: 2 | Tr...
# 1  Group Chance: 0.00227% | Unique Routes: 2 | Tr...
# 2  Group Chance: 0.00203% | Unique Routes: 2 | Tr...

# %%
for i, (_, row) in enumerate(df_cost.head(3).iterrows(), start=1):
    print(f"--- Route {i}: {row['Route']} ---")
    print(row['Pretty Print'])
# Out:
# --- Route 1: #1 ---
# Group Chance: 0.00205% | Unique Routes: 2 | Tries needed for 60%: 44,788 | Cost per Craft: 5,227 EX | Cost for 60%: 234,077,758 EX
# 1. Regal Orb (1 EX) [ROUGH (!) avg. chance: 0.79904%]
# 2. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 42.65420%]
# 3. Perfect Essence of Battle (1,400 EX) [ROUGH (!) avg. chance: 25.00000%]
# 4. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 72.03164%]
# 5. Perfect Essence of Haste (3,405 EX) [ROUGH (!) avg. chance: 20.00000%]
# 6. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
# 7. Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 25.00000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 0.00063% | Tries needed for 60%: 146,432 | Cost per Craft: 5,227 EX | Cost for 60%: 765,304,863 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Regal Orb (1 EX)
# 1.	+ [20/2503 (~0.799%), Tier 3+, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (2 EX) [TEMP]
# 2.	+ [6936/16261 (~42.654%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Battle (1,400 EX)
# 3.	- [1/4 (~25.000%), Prefix] 'any prefix (temporary)'
# 3.	+ [1/4 (~25.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 4. Apply Exalted Orb (2 EX) [TEMP]
# 4.	+ [2312/5247 (~44.063%), Prefix] 'any prefix (temporary)'
# 5. Apply Perfect Essence of Haste (3,405 EX)
# 5.	- [1/5 (~20.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 5.	+ [1/5 (~20.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 6. Apply Perfect Essence of Electricity (369 EX)
# 6.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 6.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 7. Apply Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 7.	+ [1/4 (~25.000%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 2: #2 ---
# Group Chance: 0.00227% | Unique Routes: 2 | Tries needed for 60%: 40,312 | Cost per Craft: 5,227 EX | Cost for 60%: 210,684,616 EX
# 1. Regal Orb (1 EX) [ROUGH (!) avg. chance: 0.79904%]
# 2. Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 14.28571%]
# 3. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 44.80331%]
# 4. Perfect Essence of Battle (1,400 EX) [ROUGH (!) avg. chance: 20.00000%]
# 5. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 100.00000%]
# 6. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
# 7. Perfect Essence of Haste (3,405 EX) [ROUGH (!) avg. chance: 33.33333%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 0.00114% | Tries needed for 60%: 80,624 | Cost per Craft: 5,227 EX | Cost for 60%: 421,369,232 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Regal Orb (1 EX)
# 1.	+ [20/2503 (~0.799%), Tier 3+, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 2.	+ [1/7 (~14.286%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
# 3. Apply Exalted Orb (2 EX) [TEMP]
# 3.	+ [6936/15481 (~44.803%), Prefix] 'any prefix (temporary)'
# 4. Apply Perfect Essence of Battle (1,400 EX)
# 4.	- [1/5 (~20.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 4.	+ [1/5 (~20.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 5. Apply Exalted Orb (2 EX) [TEMP]
# 5.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 6. Apply Perfect Essence of Electricity (369 EX)
# 6.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 6.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 7. Apply Perfect Essence of Haste (3,405 EX)
# 7.	- [1/3 (~33.333%), Suffix] 'any suffix (temporary)'
# 7.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
#
# --- Route 3: #3 ---
# Group Chance: 0.00203% | Unique Routes: 2 | Tries needed for 60%: 45,230 | Cost per Craft: 5,227 EX | Cost for 60%: 236,387,805 EX
# 1. Regal Orb (1 EX) [ROUGH (!) avg. chance: 0.79904%]
# 2. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 42.65420%]
# 3. Perfect Essence of Haste (3,405 EX) [ROUGH (!) avg. chance: 25.00000%]
# 4. Exalted Orb (2 EX) [ROUGH (!) avg. chance: 71.32710%]
# 5. Perfect Essence of Electricity (369 EX) [ROUGH (!) avg. chance: 33.33333%]
# 6. Perfect Essence of Battle (1,400 EX) [ROUGH (!) avg. chance: 20.00000%]
# 7. Preserved Jawbone (29 EX) + Omen of the Liege (23 EX) [ROUGH (!) avg. chance: 25.00000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 0.00142% | Tries needed for 60%: 64,523 | Cost per Craft: 5,227 EX | Cost for 60%: 337,219,773 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Regal Orb (1 EX)
# 1.	+ [20/2503 (~0.799%), Tier 3+, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (2 EX) [TEMP]
# 2.	+ [6936/16261 (~42.654%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Haste (3,405 EX)
# 3.	- [1/4 (~25.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1/4 (~25.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 4. Apply Exalted Orb (2 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Electricity (369 EX)
# 5.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 5.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 6. Apply Perfect Essence of Battle (1,400 EX)
# 6.	- [1/5 (~20.000%), Suffix] 'any suffix (temporary)'
# 6.	+ [1/5 (~20.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 7. Apply Preserved Jawbone (29 EX) + Omen of the Liege (23 EX)
# 7.	+ [1/4 (~25.000%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'

# %% [markdown]
# ## 12. Console Display Best Currency Groups

# %% [markdown]
# Here are the best currency groups (which group unique paths based on the used currencies). The goal of this statistic is to provide a general overview, over how good the applied currencies are.
#
# F. e. multiple unique paths may lead to a desired item, but each of them does not have a 100 % chance.
# BUT together they COULD have a 100 % chance. Or a higher one in general.
#
# The calculation is very memory expensive for deep routes, but if can be achieved, is worth it (IMO).

# %%
df_groups = pd.DataFrame([
    {
        'Group': f'Group {i+1}',
        'Group Chance': g.chance,
        'Group Tries Needed': group_chance_instance.calculate_tries_needed_for_60_percent(g),
        'Currencies': ', '.join(
            [' + '.join([c.get_item_name(item_info=coe_data) for c in currency_list.list])
             for currency_list in g.group]
        )
    }
    for i, g in enumerate(groups)
])

print(df_groups.head(3))
# Out:
#      Group         Group Chance  Group Tries Needed  \
# 0  Group 1  0.09114583333333331                  10
# 1  Group 2  0.09114583333333333                  10
# 2  Group 3  0.09114583333333333                  10
#
#                                           Currencies
# 0  Greater Essence of Abrasion, Exalted Orb + Ome...
# 1  Greater Essence of Abrasion, Exalted Orb + Ome...
# 2  Greater Essence of Abrasion, Exalted Orb + Ome...

# %% [markdown]
# ## 13. Visualize Top Routes and Groups
# Another example of how the results can be visualized. Same as with the pandas tables ... display the info you actually want.
# Keep in mind, the naming of routes is handled by their respective position in the sorted lists. Change to your needs.

# %%
import matplotlib.pyplot as plt

# 14a. Top Routes by Chance
plt.figure(figsize=(10, 6))
plt.bar(df_chance['Route'], df_chance['Chance'].apply(
    lambda x: x.get_raw_value() if x else 0), color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Chance')
plt.title('Top Routes by Chance')
plt.tight_layout()
plt.show()

# 14b. Top Routes by Cost per 1 (DIV)
plt.figure(figsize=(10, 6))
plt.bar(df_cost['Route'], df_cost['Cost per 1 (DIV)'].apply(
    lambda x: x if x else 0), color='salmon')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Cost per 1 (Divines)')
plt.title('Top Routes by Cost per 1 (DIV)')
plt.tight_layout()
plt.show()

# 14c. Top Routes by Cost per 1 * by tries needed for 60 percent (DIV)
heights = df_efficiency['Cost per 1 (DIV)'] * \
    df_efficiency['Tries needed for 60 %'].apply(lambda x: x if x else 0)

plt.figure(figsize=(10, 6))
plt.bar(df_efficiency['Route'], heights, color='salmon')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Cost per 1 (Divines)')
plt.title('Top Routes by Cost per 1 * Tries needed for 60 %')
plt.tight_layout()
plt.show()

# # 14d. Top Currency Groups by Chance
# plt.figure(figsize=(10, 6))
# plt.bar(df_groups['Currencies'], df_groups['Group Chance'].apply(
#     lambda x: x.get_raw_value() if x else 0), color='lightgreen')
# plt.xticks(rotation=45, ha='right')
# plt.ylabel('Group Chance')
# plt.title('Top Currency Groups by Chance')
# plt.tight_layout()
# plt.show()
