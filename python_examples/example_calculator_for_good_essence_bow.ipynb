# %% [markdown]
# # Possible Crafting Analysis Example
#
# Note 1: The structure is generated with ChatGPT, based on the pure Python example in [`example_calculator_for_example_items.py`](https://github.com/WladHD/pyoe2-craftpath/tree/main/python_examples/example_calculator_for_example_items.py).
#
# Note 2: The start and target item was provided by [github/Dboire9](https://github.com/Dboire9/), thanks!
#
# This notebook demonstrates an example workflow for calculating crafting routes in Path of Exile 2. It includes:
# - Loading example start and target items.
# - Fetching economy and item data.
# - Generating an item matrix and computing statistics.
# - Displaying results in interactive Pandas tables with pretty-print for each route.
# - Summary of top routes and currency groups.

# %% [markdown]
# ## 1. Imports and Version Check
# Import necessary modules for PoE2 crafting analysis, JSON parsing, and Pandas display.
#
# Check for new version

# %%
import pyoe2_craftpath as pc
import pandas as pd

new_version_available = pc.check_for_updates_and_print()
# Out:
# 2025-12-07T15:02:09.470061Z  INFO You are up to date running pyoe2-craftpath with version 0.4.0!
# You can always check out https://github.com/WladHD/pyoe2-craftpath if you encounter issues or have ideas.

# %% [markdown]
# ## 2. Setup Cache and URLs
# Define URLs for item data ([Craft of Exile](https://www.craftofexile.com/?game=poe2)) and market data ([PoE Ninja](https://poe.ninja/)). The economy data is gathered for the League `Rise of the Abyssal`.

# %%
COE_MAP = {
    "./cache/coe2.json": "https://www.craftofexile.com/json/poe2/main/poec_data.json"
}

ECONOMY_MAP = {
    "./cache/pn_abyss.json": "https://poe.ninja/poe2/api/economy/exchange/current/overview?league=Rise of the Abyssal&type=Abyss",
    "./cache/pn_currency.json": "https://poe.ninja/poe2/api/economy/exchange/current/overview?league=Rise of the Abyssal&type=Currency",
    "./cache/pn_essences.json": "https://poe.ninja/poe2/api/economy/exchange/current/overview?league=Rise of the Abyssal&type=Essences",
    "./cache/pn_ritual.json": "https://poe.ninja/poe2/api/economy/exchange/current/overview?league=Rise of the Abyssal&type=Ritual"
}

# %% [markdown]
# ## 3. Fetch and Parse Item and Market Data
# I've implemented a caching function, that can fetch and cache the given structure in `COE_MAP` and `ECONOMY_MAP`. Use that or provide required CoE's and PN's jsons on your own.

# %%
raw_fetched_responses_coe = pc.retrieve_contents_from_urls_with_cache_unstable_order(
    cache_url_map=COE_MAP,
    max_cache_duration_in_sec=60*60*24
)

raw_fetched_responses_economy = pc.retrieve_contents_from_urls_with_cache_unstable_order(
    cache_url_map=ECONOMY_MAP,
    max_cache_duration_in_sec=60*60
)

coe_data = pc.CraftOfExileItemInfoProvider.parse_from_json(
    raw_fetched_responses_coe[0])
economy = pc.PoeNinjaMarketPriceProvider.parse_from_json_list(
    raw_fetched_responses_economy)
# Out:
# 2025-12-07T15:02:09.489582Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/coe2.json'
# 2025-12-07T15:02:09.507525Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/pn_currency.json'
# 2025-12-07T15:02:09.510658Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/pn_abyss.json'
# 2025-12-07T15:02:09.513877Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/pn_ritual.json'
# 2025-12-07T15:02:09.516712Z  INFO retrieve_contents_from_urls_with_cache_unstable_order: Loading cached contents from './cache/pn_essences.json'

# %% [markdown]
# ## 4. Load Example Items
# Load raw string for starting and target items and parse using the `CraftOfExileEmulatorItemImport` class. The content of `startitem_good_essence_bow.json` and `targetitem_good_essence_bow.json` is generated by the Emulator in [craftofexile.com](https://www.craftofexile.com/?game=poe2) using the Export function (under History/Spending on the right).

# %%
with open('example_items/startitem_good_essence_bow.json', 'r', encoding='utf-8') as f:
    start_raw_string = f.read()
with open('example_items/targetitem_good_essence_bow.json', 'r', encoding='utf-8') as f:
    end_raw_string = f.read()

start_item = pc.CraftOfExileEmulatorItemImport.parse_itemsnapshot_from_string(
    start_raw_string, coe_data)
end_item = pc.CraftOfExileEmulatorItemImport.parse_itemsnapshot_from_string(
    end_raw_string, coe_data)

print(start_item.to_pretty_string(coe_data, True))
print(end_item.to_pretty_string(coe_data, True))
# Out:
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# [Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# [Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Rare, ItemLevel: 100, Sockets: 0
# [Tier 1+, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# [Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# [Tier 1+, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# [Tier 3+, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# [Tier 1+, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# [Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'

# %% [markdown]
# ## 5. Generate Item Matrix
# Use `MatrixBuilderPreset.HappyPathMatrixBuilder` to create a crafting matrix from start to target items. Currently only one implementation exists to build the item matrix. Refer to the [README](https://github.com/WladHD/pyoe2-craftpath) for implementation details. You can write your own Rust addon and create a new `DynMatrixBuilder`, which can be passed as the argument `matrix_builder`.

# %%
matrix_builder_instance = pc.MatrixBuilderPreset.HappyPathMatrixBuilder.get_instance()

calc = pc.Calculator.generate_item_matrix(
    starting_item=start_item,
    target=end_item,
    item_provider=coe_data,
    market_info=economy,
    matrix_builder=matrix_builder_instance
)

print(f"Matrix contains {len(calc.matrix)} items")
# Out:
# 2025-12-07T15:02:09.778603Z  INFO generate_item_matrix: Using 'Happy Path Matrix Builder' to generate item matrix ...
# 2025-12-07T15:02:09.778645Z  INFO generate_item_matrix: Description: Builds an optimized item matrix containing reachable items starting from the given item, that only come closer to the target item (target_proximity).
# 2025-12-07T15:02:09.778674Z  INFO generate_item_matrix: Starting propagation ...
# 2025-12-07T15:02:09.808265Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.808296Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.808308Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLeveMatrix contains 686 items
# l(1), bounds: Minimum } }
# 2025-12-07T15:02:09.810730Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.810758Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.810770Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.816052Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.816084Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.816096Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.827327Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.827353Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.827365Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.835634Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.835661Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.835673Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.849261Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.849288Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.849301Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.851594Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.851612Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.851623Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.854022Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.854047Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.854059Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.859558Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.859584Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.859595Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.863106Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.863124Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.863135Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.867198Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.867223Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.867234Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.870551Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.870571Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.870585Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.874586Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.874611Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.874632Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.878190Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.878210Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.878222Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.883870Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.883899Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.883911Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.888110Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.888139Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.888151Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.893884Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.893912Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.893924Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.898193Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.898224Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.898239Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.905739Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.905803Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.905822Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.921762Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.921791Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.921803Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.925915Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.925941Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.925953Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.939105Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.939133Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.939146Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.955854Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.955906Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.955926Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:09.955938Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.993012Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:09.993046Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:09.993058Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:09.993068Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.002495Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.002526Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.002537Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.002547Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.033897Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.033929Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.033941Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.033952Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.090430Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.090459Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.090471Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.090482Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.145072Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.145101Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.145113Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.145127Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.202932Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.202960Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.202972Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.202982Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.235362Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.235392Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.235404Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.235415Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.257742Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.257769Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.257781Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.257792Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.281357Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.281386Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.281398Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.281408Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.294986Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.295013Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.295025Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.295036Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.314474Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.314502Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.314514Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.314525Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.365015Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.365045Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.365057Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.365067Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.366665Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.366687Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.366698Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.366709Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.416410Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.416438Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.416450Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.416464Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.427263Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.427287Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.427298Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.427309Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.428972Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.428990Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.429001Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.429012Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.433233Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.433251Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.433262Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.433273Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.440220Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.440241Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.440253Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.440264Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.476960Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.476990Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.477002Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.477012Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.519005Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.519035Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.519047Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.519057Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.528703Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.528728Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.528740Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.528750Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.547368Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.547396Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.547408Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.547418Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.563953Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.563981Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.563992Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.564005Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.571309Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.571333Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.571344Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.571355Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.624026Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.624054Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.624066Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.624076Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.628500Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.628519Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.628530Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.628540Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.630234Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.630271Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.630285Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.630295Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.667234Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.667264Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.667276Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.667287Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.679343Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.679367Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.679379Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.679389Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.725378Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.725406Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.725418Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.725428Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.746360Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.746385Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.746397Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.746407Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.747905Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.747923Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.747934Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.747946Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.794414Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.794441Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.794453Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.794464Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.795964Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.795982Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.795994Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.796005Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.800918Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.800937Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.800949Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.800959Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.802580Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.802597Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.802609Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.802619Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.820449Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.820477Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5704), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.820489Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.820499Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.828916Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.828934Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.828945Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:10.828956Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.842072Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.842095Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.842107Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.842117Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5923), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.882272Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.882318Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.882341Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.882361Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.927950Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Exact } }
# 2025-12-07T15:02:10.927979Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:10.927991Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:10.928004Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:11.129759Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:11.129789Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:11.129802Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:11.129812Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:11.163099Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5120), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Minimum } }
# 2025-12-07T15:02:11.163128Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5118), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(3), bounds: Minimum } }
# 2025-12-07T15:02:11.163140Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5708), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:11.163151Z  INFO generate_item_matrix: AffixSpecifier { affix: AffixId(5706), fractured: false, tier: AffixTierConstraints { tier: AffixTierLevel(1), bounds: Exact } }
# 2025-12-07T15:02:11.768402Z  INFO generate_item_matrix: Excluded 1636 more expensive routes with same chance successfully
# 2025-12-07T15:02:11.768433Z  INFO generate_item_matrix: Successfully generated item matrix.

# %% [markdown]
# ## 6. Calculate Statistics
# Compute crafting statistics using analyzers for chance, efficiency, and cost. Here again, analyzer instances are of type `DynStatisticAnalyzerPaths`, if you want to handle the statistic login in Rust. You can also let this program calculate all possible paths, and create your own statistics in Python yourself.

# %%
def calculate_stat_results(calc: pc.Calculator, analyzer_preset: pc.StatisticAnalyzerPathPreset, coe_data: pc.ItemInfoProvider, economy: pc.MarketPriceProvider, max_routes=100):
    instance = analyzer_preset.get_instance()
    res = calc.calculate_statistics(
        item_provider=coe_data,
        market_provider=economy,
        max_routes=max_routes,
        max_ram_in_bytes=1_000_000_000,
        statistic_analyzer=instance
    )
    return res, instance


chance_results, chance_instance = calculate_stat_results(
    calc, pc.StatisticAnalyzerPathPreset.UniquePathChance, coe_data, economy)
efficiency_results, efficiency_instance = calculate_stat_results(
    calc, pc.StatisticAnalyzerPathPreset.UniquePathEfficiency, coe_data, economy)
cost_results, cost_instance = calculate_stat_results(
    calc, pc.StatisticAnalyzerPathPreset.UniquePathCost, coe_data, economy)
# Out:
# 2025-12-07T15:02:11.792741Z  INFO calculate_statistics: Using 'Unique Path by Highest Chance' to calculate statistics ...
# 2025-12-07T15:02:11.792783Z  INFO calculate_statistics: Description: Retrieves N number of unique paths memory efficiently from all possible combinations, sorted by chance.
# 2025-12-07T15:02:11.792808Z  INFO calculate_statistics:get_statistic: Generating unique craft paths based on item matrix
# 2025-12-07T15:02:11.984559Z  INFO calculate_statistics:get_statistic:finalize_routes: Collecting 100 routes ...
# 2025-12-07T15:02:11.985130Z  INFO calculate_statistics:get_statistic:finalize_routes: Routes collected successfully.
# 2025-12-07T15:02:11.985161Z  INFO calculate_statistics: Successfully calculated statistics.
# 2025-12-07T15:02:11.985367Z  INFO calculate_statistics: Using 'Unique Path by Efficient Cost' to calculate statistics ...
# 2025-12-07T15:02:11.985380Z  INFO calculate_statistics: Description: Retrieves N number of unique paths memory efficiently from all possible combinations, sorted by cost multiplied by amount of tries needed to reach at least 60% chance to gain the item.
# 2025-12-07T15:02:11.985399Z  INFO calculate_statistics:get_statistic: Generating unique craft paths based on item matrix
# 2025-12-07T15:02:12.408193Z  INFO calculate_statistics:get_statistic:finalize_routes: Collecting 100 routes ...
# 2025-12-07T15:02:12.408730Z  INFO calculate_statistics:get_statistic:finalize_routes: Routes collected successfully.
# 2025-12-07T15:02:12.408794Z  INFO calculate_statistics: Successfully calculated statistics.
# 2025-12-07T15:02:12.409022Z  INFO calculate_statistics: Using 'Unique Path by Lowest Cost' to calculate statistics ...
# 2025-12-07T15:02:12.409035Z  INFO calculate_statistics: Description: Retrieves N number of unique paths memory efficiently from all possible combinations, sorted by cost.
# 2025-12-07T15:02:12.409051Z  INFO calculate_statistics:get_statistic: Generating unique craft paths based on item matrix
# 2025-12-07T15:02:12.602376Z  INFO calculate_statistics:get_statistic:finalize_routes: Collecting 100 routes ...
# 2025-12-07T15:02:12.602895Z  INFO calculate_statistics:get_statistic:finalize_routes: Routes collected successfully.
# 2025-12-07T15:02:12.602947Z  INFO calculate_statistics: Successfully calculated statistics.

# %% [markdown]
# ## 7. Calculate Currency Group Statistics
# Compute grouped statistics using `CurrencyGroupChance` analyzer. Same as unique paths, but with the goal of collecting routes into groups by the applied currency sequence. The instance is `DynStatisticAnalyzerCurrencyGroups`.
#
# The calculation is memory expensive for deep paths, so define the amount of RAM you're comfortable with giving for this calculation.

# %%
group_chance_instance = pc.StatisticAnalyzerCurrencyGroupPreset.CurrencyGroupChance.get_instance()
groups = calc.calculate_statistics_currency_group(
    item_provider=coe_data,
    market_provider=economy,
    max_ram_in_bytes=1_000_000_000,
    statistic_analyzer=group_chance_instance
)
# Out:
# 2025-12-07T15:02:12.610248Z  INFO calculate_statistics_currency_group: Using 'Currency Groups by Highest Chance (No Unique Paths)' to calculate statistics ...
# 2025-12-07T15:02:12.610296Z  INFO calculate_statistics_currency_group: Description: Memory efficient implementation of currency sequence grouping. Unique paths are not kept, but instead immediatly summed, thus losing information but allowing memory efficient collection. Best combined with best N routes.
# 2025-12-07T15:02:12.610335Z  INFO calculate_statistics_currency_group:get_statistic:get_grouped_statistic_memory_efficient: Generating unique craft paths based on item matrix
# 2025-12-07T15:02:14.889582Z  INFO calculate_statistics_currency_group: Successfully calculated statistics.

# %% [markdown]
# ## 8. Build Pandas DataFrames for Routes
# Here is an example, of how the calculated data can be transformed, into a more interesting view. Keep in mind that a route per se has no name. So the position in the sorted list is to identify it (in this example).
#
# Construct DataFrames for chance, efficiency, and cost results with pretty-printed routes.

# %%
def build_routes_df(routes: list[pc.ItemRoute], analyzer_instance: pc.DynStatisticAnalyzerPaths, coe_data: pc.ItemInfoProvider, economy: pc.MarketPriceProvider, calc: pc.Calculator, groups: list[pc.GroupRoute]):
    data = []
    for i, r in enumerate(routes):
        group = r.locate_group(calculated_groups=groups)

        currency_group = [node.currency_list for node in r.route]

        data.append({
            'Route': "#" + str(i + 1),
            'Chance': r.chance,
            'Cost per 1 (DIV)': analyzer_instance.calculate_cost_per_craft(currency_group, coe_data, economy).get_divine_value(),
            'Tries needed for 60 %': analyzer_instance.calculate_tries_needed_for_60_percent(r),
            'Group Chance': group.chance if group is not None else None,
            'Group Tries Needed':  group_chance_instance.calculate_tries_needed_for_60_percent(group) if group is not None else None,
            'Pretty Print': r.to_pretty_string(
                item_provider=coe_data,
                market_provider=economy,
                calculator=calc,
                groups=groups,
                statistic_analyzer=analyzer_instance
            )
        })
    return pd.DataFrame(data)


df_chance = build_routes_df(
    chance_results, chance_instance, coe_data, economy, calc, groups)
df_efficiency = build_routes_df(
    efficiency_results, efficiency_instance, coe_data, economy, calc, groups)
df_cost = build_routes_df(cost_results, cost_instance,
                          coe_data, economy, calc, groups)

# %% [markdown]
# ### 9. Display Top Routes by Chance
# Show a Pandas DataFrame and print pretty-printed route details.
#
# Below is a simple example of how the calculated data can be used. Following examples show a printed table, as well as the raw console output I've coded to visualize routes. The information you want may be different, so adapt to your needs.

# %%
df_chance.head(3)
# Out:
#   Route               Chance  Cost per 1 (DIV)  Tries needed for 60 %  \
# 0    #1  0.07291666666666666         11.089543                     13
# 1    #2  0.07291666666666666          1.401592                     13
# 2    #3  0.07291666666666666          1.401592                     13
#
#           Group Chance  Group Tries Needed  \
# 0  0.07291666666666666                  13
# 1  0.07291666666666666                  13
# 2  0.07291666666666666                  13
#
#                                         Pretty Print
# 0  Group Chance: 7.29167% | Unique Routes: 1 | Tr...
# 1  Group Chance: 7.29167% | Unique Routes: 1 | Tr...
# 2  Group Chance: 7.29167% | Unique Routes: 1 | Tr...

# %%
for i, (_, row) in enumerate(df_chance.head(3).iterrows(), start=1):
    print(f"--- Route {i}: {row['Route']} ---")
    print(row['Pretty Print'])
# Out:
# --- Route 1: #1 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 14,772 EX | Cost for 60%: 192,027 EX
# 1. Greater Essence of Abrasion (27 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
# 4. Omen of Dextral Annulment (12,388 EX) + Orb of Annulment (516 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 6. Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 100.00000%]
# 7. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 8. Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 50.00000%]
# 9. Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 14,772 EX | Cost for 60%: 192,027 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (27 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Electricity (258 EX)
# 3.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 3.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 4. Apply Omen of Dextral Annulment (12,388 EX) + Orb of Annulment (516 EX)
# 4.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 5. Apply Exalted Orb (1 EX) [TEMP]
# 5.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 6. Apply Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX)
# 6.	- [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 6.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 7. Apply Exalted Orb (1 EX)
# 7.	+ [1 (~100.000%), Tier 8+, ilvl 1, Suffix] '+# to Dexterity'
# 8. Apply Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX)
# 8.	- [1/2 (~50.000%), Tier 8+, ilvl 1, Suffix] '+# to Dexterity'
# 8.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 9. Apply Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 9.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 2: #2 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 1. Greater Essence of Abrasion (27 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
# 6. Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 50.00000%]
# 7. Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (27 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 4. Apply Exalted Orb (1 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Electricity (258 EX)
# 5.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 5.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 6. Apply Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX)
# 6.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 6.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 7. Apply Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 3: #3 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 1. Greater Essence of Abrasion (27 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 50.00000%]
# 6. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
# 7. Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (27 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 4. Apply Exalted Orb (1 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX)
# 5.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 5.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 6. Apply Perfect Essence of Electricity (258 EX)
# 6.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 6.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 7. Apply Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'

# %% [markdown]
# ### 10. Console Display Top Routes by Efficiency

# %%
df_efficiency.head(3)
# Out:
#   Route               Chance  Cost per 1 (DIV)  Tries needed for 60 %  \
# 0    #1  0.07291666666666666          1.401592                     13
# 1    #2  0.07291666666666666          1.401592                     13
# 2    #3  0.07291666666666666          1.401592                     13
#
#           Group Chance  Group Tries Needed  \
# 0  0.07291666666666666                  13
# 1  0.07291666666666666                  13
# 2  0.07291666666666666                  13
#
#                                         Pretty Print
# 0  Group Chance: 7.29167% | Unique Routes: 1 | Tr...
# 1  Group Chance: 7.29167% | Unique Routes: 1 | Tr...
# 2  Group Chance: 7.29167% | Unique Routes: 1 | Tr...

# %%
for i, (_, row) in enumerate(df_efficiency.head(3).iterrows(), start=1):
    print(f"--- Route {i}: {row['Route']} ---")
    print(row['Pretty Print'])
# Out:
# --- Route 1: #1 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 1. Greater Essence of Abrasion (27 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
# 6. Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 50.00000%]
# 7. Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (27 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 4. Apply Exalted Orb (1 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Electricity (258 EX)
# 5.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 5.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 6. Apply Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX)
# 6.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 6.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 7. Apply Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 2: #2 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 1. Greater Essence of Abrasion (27 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
# 6. Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 50.00000%]
# 7. Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (27 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 4. Apply Exalted Orb (1 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Electricity (258 EX)
# 5.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 5.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 6. Apply Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX)
# 6.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 6.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 7. Apply Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 3: #3 ---
# Group Chance: 7.29167% | Unique Routes: 1 | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 1. Greater Essence of Abrasion (27 EX) [ROUGH (!) avg. chance: 100.00000%]
# 2. Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [ROUGH (!) avg. chance: 100.00000%]
# 3. Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 100.00000%]
# 4. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 5. Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX) [ROUGH (!) avg. chance: 50.00000%]
# 6. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
# 7. Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 43.75000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 7.29167% | Tries needed for 60%: 13 | Cost per Craft: 1,867 EX | Cost for 60%: 24,270 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Essence of Abrasion (27 EX)
# 1.	+ [1 (~100.000%), Tier 3=, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (1 EX) + Omen of Sinistral Exaltation (32 EX) [TEMP]
# 2.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Battle (297 EX) + Omen of Dextral Crystallisation (302 EX)
# 3.	- [1 (~100.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1 (~100.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 4. Apply Exalted Orb (1 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Haste (179 EX) + Omen of Dextral Crystallisation (302 EX)
# 5.	- [1/2 (~50.000%), Suffix] 'any suffix (temporary)'
# 5.	+ [1/2 (~50.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 6. Apply Perfect Essence of Electricity (258 EX)
# 6.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 6.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 7. Apply Omen of Abyssal Echoes (465 EX) + Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 7.	+ [7/16 (~43.750%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'

# %% [markdown]
# ### 11. Console Display Top Routes by Cost

# %%
df_cost.head(3)
# Out:
#   Route                   Chance  Cost per 1 (DIV)  Tries needed for 60 %  \
# 0    #1  0.000025890756745917436          0.556663                  35391
# 1    #2   0.00003235160394830616          0.556663                  28323
# 2    #3  0.000025890756745917436          0.556663                  35391
#
#              Group Chance  Group Tries Needed  \
# 0  0.00005178151349183487               17695
# 1  0.00004615092286998696               19854
# 2  0.00005178151349183487               17695
#
#                                         Pretty Print
# 0  Group Chance: 0.00518% | Unique Routes: 2 | Tr...
# 1  Group Chance: 0.00462% | Unique Routes: 2 | Tr...
# 2  Group Chance: 0.00518% | Unique Routes: 2 | Tr...

# %%
for i, (_, row) in enumerate(df_cost.head(3).iterrows(), start=1):
    print(f"--- Route {i}: {row['Route']} ---")
    print(row['Pretty Print'])
# Out:
# --- Route 1: #1 ---
# Group Chance: 0.00518% | Unique Routes: 2 | Tries needed for 60%: 17,695 | Cost per Craft: 742 EX | Cost for 60%: 13,120,404 EX
# 1. Greater Regal Orb (1 EX) [ROUGH (!) avg. chance: 1.82031%]
# 2. Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 14.28571%]
# 3. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 44.80331%]
# 4. Perfect Essence of Battle (297 EX) [ROUGH (!) avg. chance: 20.00000%]
# 5. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 6. Perfect Essence of Haste (179 EX) [ROUGH (!) avg. chance: 33.33333%]
# 7. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 0.00259% | Tries needed for 60%: 35,391 | Cost per Craft: 742 EX | Cost for 60%: 26,241,549 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Regal Orb (1 EX)
# 1.	+ [140/7691 (~1.820%), Tier 3+, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 2.	+ [1/7 (~14.286%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
# 3. Apply Exalted Orb (1 EX) [TEMP]
# 3.	+ [6936/15481 (~44.803%), Prefix] 'any prefix (temporary)'
# 4. Apply Perfect Essence of Battle (297 EX)
# 4.	- [1/5 (~20.000%), Prefix] 'any prefix (temporary)'
# 4.	+ [1/5 (~20.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 5. Apply Exalted Orb (1 EX) [TEMP]
# 5.	+ [1 (~100.000%), Prefix] 'any prefix (temporary)'
# 6. Apply Perfect Essence of Haste (179 EX)
# 6.	- [1/3 (~33.333%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 6.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 7. Apply Perfect Essence of Electricity (258 EX)
# 7.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 7.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
#
# --- Route 2: #2 ---
# Group Chance: 0.00462% | Unique Routes: 2 | Tries needed for 60%: 19,854 | Cost per Craft: 742 EX | Cost for 60%: 14,721,249 EX
# 1. Greater Regal Orb (1 EX) [ROUGH (!) avg. chance: 1.82031%]
# 2. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 42.65420%]
# 3. Perfect Essence of Haste (179 EX) [ROUGH (!) avg. chance: 25.00000%]
# 4. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 71.32710%]
# 5. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
# 6. Perfect Essence of Battle (297 EX) [ROUGH (!) avg. chance: 20.00000%]
# 7. Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 25.00000%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 0.00324% | Tries needed for 60%: 28,323 | Cost per Craft: 742 EX | Cost for 60%: 21,000,802 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Regal Orb (1 EX)
# 1.	+ [140/7691 (~1.820%), Tier 3+, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Exalted Orb (1 EX) [TEMP]
# 2.	+ [6936/16261 (~42.654%), Prefix] 'any prefix (temporary)'
# 3. Apply Perfect Essence of Haste (179 EX)
# 3.	- [1/4 (~25.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 3.	+ [1/4 (~25.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 4. Apply Exalted Orb (1 EX) [TEMP]
# 4.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 5. Apply Perfect Essence of Electricity (258 EX)
# 5.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 5.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 6. Apply Perfect Essence of Battle (297 EX)
# 6.	- [1/5 (~20.000%), Suffix] 'any suffix (temporary)'
# 6.	+ [1/5 (~20.000%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'
# 7. Apply Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 7.	+ [1/4 (~25.000%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
#
# --- Route 3: #3 ---
# Group Chance: 0.00518% | Unique Routes: 2 | Tries needed for 60%: 17,695 | Cost per Craft: 742 EX | Cost for 60%: 13,120,404 EX
# 1. Greater Regal Orb (1 EX) [ROUGH (!) avg. chance: 1.82031%]
# 2. Preserved Jawbone (7 EX) + Omen of the Liege (1 EX) [ROUGH (!) avg. chance: 14.28571%]
# 3. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 44.80331%]
# 4. Perfect Essence of Haste (179 EX) [ROUGH (!) avg. chance: 20.00000%]
# 5. Exalted Orb (1 EX) [ROUGH (!) avg. chance: 100.00000%]
# 6. Perfect Essence of Electricity (258 EX) [ROUGH (!) avg. chance: 33.33333%]
# 7. Perfect Essence of Battle (297 EX) [ROUGH (!) avg. chance: 33.33333%]
#
# Base Group: Two-Handed Weapons (#7), Max Rarity: Rare, Max Affixes: 6 (3 per side), Max. Sockets: 2 (3 corrupt)
# BaseId: #20, Rarity: Magic, ItemLevel: 100, Sockets: 0
# Exact Chance: 0.00259% | Tries needed for 60%: 35,391 | Cost per Craft: 742 EX | Cost for 60%: 26,241,549 EX
# 0. Starting with ...
# 0.	[Tier 1+, ilvl 82, Prefix] '#% increased Physical Damage'
# 0.	[Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 1. Apply Greater Regal Orb (1 EX)
# 1.	+ [140/7691 (~1.820%), Tier 3+, ilvl 60, Prefix] 'Adds # to # Physical Damage'
# 1. 	! Rarity Magic -> Rare
# 2. Apply Preserved Jawbone (7 EX) + Omen of the Liege (1 EX)
# 2.	+ [1/7 (~14.286%), Tier 1+, ilvl 65, Suffix, Des.] '#% increased Attack Speed, Companions have #% increased Attack Speed'
# 3. Apply Exalted Orb (1 EX) [TEMP]
# 3.	+ [6936/15481 (~44.803%), Prefix] 'any prefix (temporary)'
# 4. Apply Perfect Essence of Haste (179 EX)
# 4.	- [1/5 (~20.000%), Tier 2+, ilvl 66, Suffix] '+# to Dexterity'
# 4.	+ [1/5 (~20.000%), Tier 1=, ilvl 72, Suffix, Ess.] '#% chance to gain Onslaught on Killing Hits with this Weapon'
# 5. Apply Exalted Orb (1 EX) [TEMP]
# 5.	+ [1 (~100.000%), Suffix] 'any suffix (temporary)'
# 6. Apply Perfect Essence of Electricity (258 EX)
# 6.	- [1/3 (~33.333%), Prefix] 'any prefix (temporary)'
# 6.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Prefix, Ess.] 'Gain #% of Damage as Extra Lightning Damage'
# 7. Apply Perfect Essence of Battle (297 EX)
# 7.	- [1/3 (~33.333%), Suffix] 'any suffix (temporary)'
# 7.	+ [1/3 (~33.333%), Tier 1=, ilvl 72, Suffix, Ess.] '+# to Level of all Attack Skills'

# %% [markdown]
# ## 12. Console Display Best Currency Groups

# %% [markdown]
# Here are the best currency groups (which group unique paths based on the used currencies). The goal of this statistic is to provide a general overview, over how good the applied currencies are.
#
# F. e. multiple unique paths may lead to a desired item, but each of them does not have a 100 % chance.
# BUT together they COULD have a 100 % chance. Or a higher one in general.
#
# The calculation is very memory expensive for deep routes, but if can be achieved, is worth it (IMO).

# %%
df_groups = pd.DataFrame([
    {
        'Group': f'Group {i+1}',
        'Group Chance': g.chance,
        'Group Tries Needed': group_chance_instance.calculate_tries_needed_for_60_percent(g),
        'Currencies': ', '.join(
            [' + '.join([c.get_item_name(item_info=coe_data) for c in currency_list.list])
             for currency_list in g.group]
        )
    }
    for i, g in enumerate(groups)
])

print(df_groups.head(3))
# Out:
#      Group         Group Chance  Group Tries Needed  \
# 0  Group 1  0.09114583333333333                  10
# 1  Group 2  0.09114583333333331                  10
# 2  Group 3  0.09114583333333333                  10
#
#                                           Currencies
# 0  Greater Essence of Abrasion, Exalted Orb + Ome...
# 1  Greater Essence of Abrasion, Exalted Orb + Ome...
# 2  Greater Essence of Abrasion, Exalted Orb + Ome...

# %% [markdown]
# ## 13. Visualize Top Routes and Groups
# Another example of how the results can be visualized. Same as with the pandas tables ... display the info you actually want.
# Keep in mind, the naming of routes is handled by their respective position in the sorted lists. Change to your needs.

# %%
import matplotlib.pyplot as plt

# 14a. Top Routes by Chance
plt.figure(figsize=(10, 6))
plt.bar(df_chance['Route'], df_chance['Chance'].apply(
    lambda x: x.get_raw_value() if x else 0), color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Chance')
plt.title('Top Routes by Chance')
plt.tight_layout()
plt.show()

# 14b. Top Routes by Cost per 1 (DIV)
plt.figure(figsize=(10, 6))
plt.bar(df_cost['Route'], df_cost['Cost per 1 (DIV)'].apply(
    lambda x: x if x else 0), color='salmon')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Cost per 1 (Divines)')
plt.title('Top Routes by Cost per 1 (DIV)')
plt.tight_layout()
plt.show()

# 14c. Top Routes by Cost per 1 * by tries needed for 60 percent (DIV)
heights = df_efficiency['Cost per 1 (DIV)'] * \
    df_efficiency['Tries needed for 60 %'].apply(lambda x: x if x else 0)

plt.figure(figsize=(10, 6))
plt.bar(df_efficiency['Route'], heights, color='salmon')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Cost per 1 (Divines)')
plt.title('Top Routes by Cost per 1 * Tries needed for 60 %')
plt.tight_layout()
plt.show()

# # 14d. Top Currency Groups by Chance
# plt.figure(figsize=(10, 6))
# plt.bar(df_groups['Currencies'], df_groups['Group Chance'].apply(
#     lambda x: x.get_raw_value() if x else 0), color='lightgreen')
# plt.xticks(rotation=45, ha='right')
# plt.ylabel('Group Chance')
# plt.title('Top Currency Groups by Chance')
# plt.tight_layout()
# plt.show()
